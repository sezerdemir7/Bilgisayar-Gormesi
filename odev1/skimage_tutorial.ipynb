# %%
# %pylab inline
# Out:
# %pylab is deprecated, use %matplotlib inline and import the required libraries.
# Populating the interactive namespace from numpy and matplotlib
# C:\Users\Demirr\PycharmProjects\bilgisayargrmesi\.venv\Lib\site-packages\IPython\core\magics\pylab.py:166: UserWarning: pylab import has clobbered these variables: ['gradient', 'text']
# `%matplotlib` prevents importing * from pylab and numpy
#   warn("pylab import has clobbered these variables: %s"  % clobbered +

# %%
from skimage import data
from skimage import io
from matplotlib import pyplot as plt

# %% [markdown]
# # Playing with colors

# %%
from skimage import color

# %% [markdown]
# Let's load some sample images.

# %%
astronaut = data.astronaut()
io.imshow(astronaut)
io.show()

# %%
astronaut_gray = color.rgb2gray(astronaut)
io.imshow(astronaut_gray)

# %% [markdown]
# # Gradients

# %%
import numpy as np
from skimage.filters.rank import gradient

# %%
grad_y = np.diff(astronaut_gray, axis=0)
io.imshow(grad_y, cmap='gray')

# %%
grad_x = np.diff(astronaut_gray, axis=1)
io.imshow(grad_x, cmap='gray')

# %% [markdown]
# **Note: across the dimention of the gradient the size of the gradient image is the size of original - 1**

# %% [markdown]
# # [Filters](http://scikit-image.org/docs/0.10.x/api/skimage.filter.html)

# %%
from skimage import filters

# %% [markdown]
# ## Gaussian

# %%
filtered = filters.gaussian(astronaut, sigma=3, multichannel=True)
io.imshow(filtered)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[34], line 1
# ----> 1 filtered = filters.gaussian(astronaut, sigma=3, multichannel=True)
#       2 io.imshow(filtered)
#
# File ~\PycharmProjects\bilgisayargrmesi\.venv\Lib\site-packages\skimage\_shared\utils.py:321, in deprecate_parameter.__call__.<locals>.fixed_func(*args, **kwargs)
#     317     elif self.new_name is not None:
#     318         # Assign old value to new one
#     319         kwargs[self.new_name] = deprecated_value
# --> 321 return func(*args, **kwargs)
#
# TypeError: gaussian() got an unexpected keyword argument 'multichannel'

# %% [markdown]
# We can specify different sigma for x and y:

# %%
filtered = filters.gaussian(astronaut, sigma=[1, 10], multichannel=True)
io.imshow(filtered)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 filtered = filters.gaussian(astronaut, sigma=[1, 10], multichannel=True)
#       2 io.imshow(filtered)
#
# File ~\PycharmProjects\bilgisayargrmesi\.venv\Lib\site-packages\skimage\_shared\utils.py:321, in deprecate_parameter.__call__.<locals>.fixed_func(*args, **kwargs)
#     317     elif self.new_name is not None:
#     318         # Assign old value to new one
#     319         kwargs[self.new_name] = deprecated_value
# --> 321 return func(*args, **kwargs)
#
# TypeError: gaussian() got an unexpected keyword argument 'multichannel'

# %%
filtered.shape == astronaut.shape
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 filtered.shape == astronaut.shape
#
# NameError: name 'filtered' is not defined

# %% [markdown]
# ## Sobel

# %%
text = data.text()
io.imshow(text)

# %%
edges = filters.sobel(text)
io.imshow(edges)

# %% [markdown]
# ## Canny

# %%
io.imshow(astronaut_gray)

# %%
from skimage import feature

edges = feature.canny(astronaut_gray)
io.imshow(edges)

# %% [markdown]
# Let's set some parameters for the blur and thresholding.

# %%
edges = feature.canny(astronaut_gray, sigma=2)
io.imshow(edges)

# %%
edges = feature.canny(astronaut_gray, sigma=1, low_threshold=0.2, high_threshold=0.5)
io.imshow(edges)

# %% [markdown]
# # [Features](http://scikit-image.org/docs/0.10.x/api/skimage.feature.html)

# %%
from skimage.feature import corner_harris, peak_local_max, corner_peaks

# %% [markdown]
# ## Harris corner detector

# %% [markdown]
# Compute the corner measure based on the autocorrelation matrix.

# %%
image = color.rgb2gray(data.text())
corners = corner_harris(image)
io.imshow(corners, cmap='gray')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[24], line 1
# ----> 1 image = color.rgb2gray(data.text())
#       2 corners = corner_harris(image)
#       3 io.imshow(corners, cmap='gray')
#
# File ~\PycharmProjects\bilgisayargrmesi\.venv\Lib\site-packages\skimage\_shared\utils.py:438, in channel_as_last_axis.__call__.<locals>.fixed_func(*args, **kwargs)
#     435 channel_axis = kwargs.get('channel_axis', None)
#     437 if channel_axis is None:
# --> 438     return func(*args, **kwargs)
#     440 # TODO: convert scalars to a tuple in anticipation of eventually
#     441 #       supporting a tuple of channel axes. Right now, only an
#     442 #       integer or a single-element tuple is supported, though.
#     443 if np.isscalar(channel_axis):
#
# File ~\PycharmProjects\bilgisayargrmesi\.venv\Lib\site-packages\skimage\color\colorconv.py:982, in rgb2gray(rgb, channel_axis)
#     941 @channel_as_last_axis(multichannel_output=False)
#     942 def rgb2gray(rgb, *, channel_axis=-1):
#     943     """Compute luminance of an RGB image.
#     944
#     945     Parameters
#    (...)
#     980     >>> img_gray = rgb2gray(img)
#     981     """
# --> 982     rgb = _prepare_colorarray(rgb)
#     983     coeffs = np.array([0.2125, 0.7154, 0.0721], dtype=rgb.dtype)
#     984     return rgb @ coeffs
#
# File ~\PycharmProjects\bilgisayargrmesi\.venv\Lib\site-packages\skimage\color\colorconv.py:170, in _prepare_colorarray(arr, force_copy, channel_axis)
#     165 if arr.shape[channel_axis] != 3:
#     166     msg = (
#     167         f'the input array must have size 3 along `channel_axis`, '
#     168         f'got {arr.shape}'
#     169     )
# --> 170     raise ValueError(msg)
#     172 float_dtype = _supported_float_type(arr.dtype)
#     173 if float_dtype == np.float32:
#
# ValueError: the input array must have size 3 along `channel_axis`, got (172, 448)

# %% [markdown]
# Now let's pick the actual corners: here we simply find the miximum peaks.

# %%
coords = peak_local_max(corners)
io.imshow(image, cmap='gray')
plt.plot(coords[:, 1], coords[:, 0], '+r', markersize=10)
plt.show()

# %% [markdown]
# Set blur intensity and distance between the peaks.

# %%
coords = peak_local_max(corner_harris(image, sigma=5), min_distance=10)
io.imshow(image, cmap='gray')
plt.plot(coords[:, 1], coords[:, 0], '+r', markersize=10)
plt.show()

# %% [markdown]
# A fancier corner selection technique: suppresses multiple connected peaks with `corner_peaks`.

# %% [markdown]
# # Template matching

# %%
from skimage.feature import match_template

# %%
image = data.coins()
io.imshow(image)

# %% [markdown]
# Let's pick a coin to localize: the one in row 3, column 2.

# %%
coin = image[170:220, 75:130]
io.imshow(coin)

# %%
match = match_template(image, coin)
io.imshow(match)

# %%
import numpy as np
import matplotlib.pyplot as plt

from skimage import data
from skimage.feature import match_template


image = data.coins()
coin = image[170:220, 75:130]

result = match_template(image, coin)
ij = np.unravel_index(np.argmax(result), result.shape)
x, y = ij[::-1]

fig, (ax1, ax2, ax3) = plt.subplots(ncols=3, figsize=(8, 3))

ax1.imshow(coin, cmap='gray')
ax1.set_axis_off()
ax1.set_title('template')

ax2.imshow(image, cmap='gray')
ax2.set_axis_off()
ax2.set_title('image')
# highlight matched region
hcoin, wcoin = coin.shape
rect = plt.Rectangle((x, y), wcoin, hcoin, edgecolor='r', facecolor='none')
ax2.add_patch(rect)

ax3.imshow(result)
ax3.set_axis_off()
ax3.set_title('`match_template`\nresult')
# highlight matched region
ax3.autoscale(False)
ax3.plot(x, y, 'o', markeredgecolor='r', markerfacecolor='none', markersize=10)

plt.show()
